# %% [markdown]
# <a href="https://colab.research.google.com/github/miguel-duque06/exercicios_introducao_ciencia_dados/blob/main/ListaExercicios_1_PythonExpress.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***
# ## **<center>Lista de Exercícios 1 - Python Express</center>**
#
#
# **<center>Introdução a Ciência de Dados</center>**
# ***
#
# <br>
#
# Segue uma lista de exercícios abordando o conteúdo inicial para a programação em Python.
#
# Cada exercício deve ser respondido em uma célula específica.
#
#
# 1) Elabore um código que imprima a mensagem *"Olá terráqueos!!"* na tela.
#
#
# 2) Elabore um código que peça um número e então mostre a mensagem: *"O número informado foi [número]."*
#
#
# 3) Elabore um código que peça dois números e imprima a soma.
#
#
# 4) Elabore um código que peça as 4 notas bimestrais e mostre a média.
#
# 5) Elabore um código que converta metros para centímetros.
#
#
# 6) Elabore um código que peça o raio de um círculo, calcule e mostre sua área.
#
# 7) Elabore um código que calcule a área de um quadrado, em seguida mostre o dobro desta área para o usuário.
#
#
# 8) Elabore um código que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês em uma mensagem amigável.
#
#
# 9) Elabore um código que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# ** Onde C = 5 * ((F-32) / 9)**.
#
#
# 10) Elabore um código que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
#
#
# 11) Elabore um código que peça 2 números inteiros e um número real. Calcule e mostre:
# * o produto do dobro do primeiro com metade do segundo .
# * a soma do triplo do primeiro com o terceiro.
# * o terceiro elevado ao cubo.
#
# 12) Elabore um código que receba os dados de entrada a altura de uma pessoa, e informe qual seria o peso ideal, usando a seguinte fórmula: (72.7*altura) - 58

# %%
# 1) Elabore um código que imprima a mensagem *"Olá terráqueos!!"* na tela.

print("Olá terráqueos")
# Out:
# Olá terráqueos

# %%
# 2) Elabore um código que peça um número e então mostre a mensagem: *"O número informado foi [número]."*

numero = input("Digite um número: ")
print("O número informado foi", numero)
# Out:
# Digite um número: 4
# O número informado foi 4

# %%
#3) Elabore um código que peça dois números e imprima a soma.

numero1 = int(input("Digite um número: "))
numero2 = int(input("Digite outro número: "))

print(f'{numero1} + {numero2} = {numero1 + numero2}')
# Out:
# Digite um número: 3
# Digite outro número: 6
# 3 + 6 = 9

# %%
# 4) Elabore um código que peça as 4 notas bimestrais e mostre a média.

nota1 = float(input("Digite a nota do primeiro bimestre: "))
nota2 = float(input("Digite a nota do segundo bimestre: "))
nota3 = float(input("Digite a nota do terceiro bimestre: "))
nota4 = float(input("Digite a nota do quarto bimestre: "))

print(f'A média das notas é {(nota1 + nota2 + nota3 + nota4) / 4}')
# Out:
# Digite a nota do primeiro bimestre: 10
# Digite a nota do segundo bimestre: 6
# Digite a nota do terceiro bimestre: 7
# Digite a nota do quarto bimestre: 8
# A média das notas é 7.75

# %%
# 5) Elabore um código que converta metros para centímetros.

metros = float(input("Digite a medida em metros: "))

print(f'{metros}m = {metros * 100}cm')
# Out:
# Digite a medida em metros: 10
# 10.0m = 1000.0cm

# %%
# 6) Elabore um código que peça o raio de um círculo, calcule e mostre sua área.

raio = float(input("Digite o raio do círculo: "))

print(f'A área do círculo é de {3.14 * (raio ** 2):.2f}')
# Out:
# Digite o raio do círculo: 34
# A área do círculo é 3629.84

# %%
# 7) Elabore um código que calcule a área de um quadrado, em seguida mostre o dobro desta área para o usuário.

lado = float(input("Digite o comprimento de um lado do quadrado: "))
area = lado ** 2

print(f'A área do quadrado é {area} e dobro dela é {area * 2}')
# Out:
# Digite o comprimento de um lado do quadrado: 20
# A área do quadrado é 400.0 e dobro dela é 800.0

# %%
# 8) Elabore um código que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês em uma mensagem amigável.

valor_hora = float(input("Quanto você ganha por hora? "))
horas_trabalhadas = float(input("Quantas horas você trabalha no mês? "))

print(f'Você receberá R${valor_hora * horas_trabalhadas} por mês')
# Out:
# Quanto você ganha por hora? 30
# Quantas horas você trabalha no mês? 120
# Você receberá R$3600.0 por mês

# %%
# 9) Elabore um código que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius. Onde C = 5 * ((F-32) / 9).

f = float(input("Digite a temperatura em Fahrenheit: "))

c = 5 * ((f - 32) / 9)

print(f'A temperatura é de {c:.2f}°C')
# Out:
# Digite a temperatura em Fahrenheit: 40
# A temperatura é de 4.44°C

# %%
# 10) Elabore um código que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.

c = float(input("Digite a temperatura em Celsius: "))

f = (c * 9/5) + 32

print(f'A temperatura é de {f}°F')
# Out:
# Digite a temperatura em Celsius: 32
# A temperatura é de 89.6°F

# %%
# 11) Elabore um código que peça 2 números inteiros e um número real. Calcule e mostre:
# 1. O produto do dobro do primeiro com metade do segundo .
# 2. A soma do triplo do primeiro com o terceiro.
# 3. O terceiro elevado ao cubo.

numero1 = int(input("Digite outro número inteiro: "))
numero2 = int(input("Digite outro número inteiro: "))
numero3 = float(input("Digite um número real: "))

print(f'1. ({numero1} * 2) * ({numero2} / 2) = {(numero1 * 2) * (numero2 / 2)}')
print(f'2. ({numero1} * 3) + {numero3} = {(numero1 * 3) + numero3}')
print(f'3. {numero3} ** 3 = {numero3 ** 3}')
# Out:
# Digite outro número inteiro: -1
# Digite outro número inteiro: 5
# Digite um número real: 3
# 1. (-1 * 2) * (5 / 2) = -5.0
# 2. (-1 * 3) + 3.0 = 0.0
# 3. 3.0 ** 3 = 27.0

# %%
# 12) Elabore um código que receba os dados de entrada a altura de uma pessoa, e informe qual seria o peso ideal, usando a seguinte fórmula: (72.7*altura) - 58

altura = float(input("Digite a sua altura: "))

print(f'Seu peso ideal é de {(72.7*altura) - 58:.2f} quilos')
# Out:
# Digite a sua altura: 1.80
# Seu peso ideal é de 72.86 quilos
